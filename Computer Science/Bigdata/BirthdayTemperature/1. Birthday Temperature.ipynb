# %% [markdown]
# # 나의 생일날 평균, 최고, 최저 기온
# #### Data
# - 기상청 국가기후데이터센터 (쓸모없는 데이터 셀 삭제)
#
# #### [참고자료](https://github.com/c0mb-dev)

# %%
# 나의 생일 10월20일 필터링
import csv 
f = open('1. seoul.csv', 'r', encoding='cp949') 
data = csv.reader(f, delimiter=',') 
for row in data :
    if row[0][5:] == '10-20':
        print(row)
f.close()
# Out:
# ['1989-10-20', '11.1', '7.3', '16.2']
# ['1990-10-20', '15.1', '10.9', '21.8']
# ['1991-10-20', '9.8', '5.2', '14.1']
# ['1992-10-20', '14.2', '8.6', '20.4']
# ['1993-10-20', '14.5', '8.6', '20.7']
# ['1994-10-20', '13.3', '8.6', '19.5']
# ['1995-10-20', '16', '9.8', '21.6']
# ['1996-10-20', '13.9', '9.6', '19.6']
# ['1997-10-20', '19.1', '13.3', '24.9']
# ['1998-10-20', '11.4', '4.9', '19.5']
# ['1999-10-20', '13.2', '7', '19.8']
# ['2000-10-20', '15.9', '11.8', '20.9']
# ['2001-10-20', '15.7', '10', '21']
# ['2002-10-20', '13.6', '11.9', '15.5']
# ['2003-10-20', '12.4', '8.3', '17.5']
# ['2004-10-20', '16.9', '12.6', '23.2']
# ['2005-10-20', '15.8', '11.1', '21.7']
# ['2006-10-20', '19.1', '16', '23.5']
# ['2007-10-20', '6.2', '3.2', '9.6']
# ['2008-10-20', '18.6', '13.5', '25.5']
# ['2009-10-20', '10.8', '6.2', '15.6']
# ['2010-10-20', '15.2', '12.7', '19.5']
# ['2011-10-20', '15.5', '11', '20.9']
# ['2012-10-20', '15.8', '10.5', '21']
# ['2013-10-20', '16.7', '11.7', '22.9']
# ['2014-10-20', '14.4', '12.9', '17.1']
# ['2015-10-20', '18.8', '15.4', '25.1']
# ['2016-10-20', '18.6', '12.9', '25.8']
# ['2017-10-20', '17', '11.1', '24.2']
# ['2018-10-20', '13.4', '6.9', '21.4']

# %%
#리스트를 생성하고 데이터 프레임으로 생성
import csv 
import pandas as pd

b_date = []
a_temperature = []
l_temperature = []
h_temperature = []


f = open('1. seoul.csv', 'r', encoding='cp949') 
data = csv.reader(f, delimiter=',') 
for row in data :
    if row[0][5:] == '10-20':
        b_date.append(row[0])
        a_temperature.append(row[1])
        l_temperature.append(row[2])
        h_temperature.append(row[3])
        
f.close() 

b_calendar = pd.DataFrame({"날짜": b_date, "평균 기온": a_temperature,\
                           "최저 기온": l_temperature, "최고 기온": h_temperature})
b_calendar #출력
# Out:
#             날짜 평균 기온 최저 기온 최고 기온
# 0   1989-10-20  11.1   7.3  16.2
# 1   1990-10-20  15.1  10.9  21.8
# 2   1991-10-20   9.8   5.2  14.1
# 3   1992-10-20  14.2   8.6  20.4
# 4   1993-10-20  14.5   8.6  20.7
# 5   1994-10-20  13.3   8.6  19.5
# 6   1995-10-20    16   9.8  21.6
# 7   1996-10-20  13.9   9.6  19.6
# 8   1997-10-20  19.1  13.3  24.9
# 9   1998-10-20  11.4   4.9  19.5
# 10  1999-10-20  13.2     7  19.8
# 11  2000-10-20  15.9  11.8  20.9
# 12  2001-10-20  15.7    10    21
# 13  2002-10-20  13.6  11.9  15.5
# 14  2003-10-20  12.4   8.3  17.5
# 15  2004-10-20  16.9  12.6  23.2
# 16  2005-10-20  15.8  11.1  21.7
# 17  2006-10-20  19.1    16  23.5
# 18  2007-10-20   6.2   3.2   9.6
# 19  2008-10-20  18.6  13.5  25.5
# 20  2009-10-20  10.8   6.2  15.6
# 21  2010-10-20  15.2  12.7  19.5
# 22  2011-10-20  15.5    11  20.9
# 23  2012-10-20  15.8  10.5    21
# 24  2013-10-20  16.7  11.7  22.9
# 25  2014-10-20  14.4  12.9  17.1
# 26  2015-10-20  18.8  15.4  25.1
# 27  2016-10-20  18.6  12.9  25.8
# 28  2017-10-20    17  11.1  24.2
# 29  2018-10-20  13.4   6.9  21.4

# %%
import numpy as np #데이터 분석 라이브러리
#https://www.cubrid.org/manual/ko/9.1.0/sql/datatype.html
#https://stackoverflow.com/questions/31917964/python-numpy-cannot-convert-datetime64ns-to-datetime64d-to-use-with-numba

b_calendar.info()
b_calendar['날짜'] = b_calendar['날짜'].astype('datetime64[ns]')
b_calendar['최고 기온'] = b_calendar['최고 기온'].astype(float)
b_calendar['최저 기온'] = b_calendar['최저 기온'].astype(float)
b_calendar['평균 기온'] = b_calendar['평균 기온'].astype(float)
print("******************데이터 변환******************")
b_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      30 non-null     object
#  1   평균 기온   30 non-null     object
#  2   최저 기온   30 non-null     object
#  3   최고 기온   30 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB
# ******************데이터 변환******************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      30 non-null     datetime64[ns]
#  1   평균 기온   30 non-null     float64
#  2   최저 기온   30 non-null     float64
#  3   최고 기온   30 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 1.1 KB

# %%
b_calendar.sort_values(by='최저 기온').head()
#2007년 10월 20일이 제일 추웠음
# Out:
#            날짜  평균 기온  최저 기온  최고 기온
# 18 2007-10-20    6.2    3.2    9.6
# 9  1998-10-20   11.4    4.9   19.5
# 2  1991-10-20    9.8    5.2   14.1
# 20 2009-10-20   10.8    6.2   15.6
# 29 2018-10-20   13.4    6.9   21.4

# %%
b_calendar.sort_values(by='최고 기온', axis=0, ascending=False).head() 
#2016년 10월 20일이 제일 더움
# Out:
#            날짜  평균 기온  최저 기온  최고 기온
# 27 2016-10-20   18.6   12.9   25.8
# 19 2008-10-20   18.6   13.5   25.5
# 26 2015-10-20   18.8   15.4   25.1
# 8  1997-10-20   19.1   13.3   24.9
# 28 2017-10-20   17.0   11.1   24.2

# %%
b_calendar.sort_values(by='평균 기온', axis=0, ascending=False).head()
# Out:
#            날짜  평균 기온  최저 기온  최고 기온
# 17 2006-10-20   19.1   16.0   23.5
# 8  1997-10-20   19.1   13.3   24.9
# 26 2015-10-20   18.8   15.4   25.1
# 19 2008-10-20   18.6   13.5   25.5
# 27 2016-10-20   18.6   12.9   25.8

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %matplotlib inline
#%matplotlib inline, notebook을 실행한 브라우저에서 바로 그림을 볼 수 있게 해줌 
#[출처]https://korbillgates.tistory.com/85

font_path = '/Users/yjk/TIL-main/TIL/Computer Science/Bigdata/font/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path, size=18)
#폰트 설정


plt.figure(figsize=(20,10))
plt.plot(b_calendar['날짜'], b_calendar['평균 기온'], 'rs--') #rs--, 스타일
plt.title('날짜별 기온', fontproperties=fontprop)
plt.ylabel('기온', fontproperties=fontprop)
plt.xlabel('날짜', fontproperties=fontprop)
plt.grid()
plt.show()

#날짜의 데이터가 XXXX-10-20 로 되어 있어서 그래프가 밀려나는 현상

# %%
b_calendar['날짜'] = b_calendar['날짜'].dt.year
b_calendar['날짜']
#년도만 가져옴
# Out:
# 0     1989
# 1     1990
# 2     1991
# 3     1992
# 4     1993
# 5     1994
# 6     1995
# 7     1996
# 8     1997
# 9     1998
# 10    1999
# 11    2000
# 12    2001
# 13    2002
# 14    2003
# 15    2004
# 16    2005
# 17    2006
# 18    2007
# 19    2008
# 20    2009
# 21    2010
# 22    2011
# 23    2012
# 24    2013
# 25    2014
# 26    2015
# 27    2016
# 28    2017
# 29    2018
# Name: 날짜, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(b_calendar['날짜'], b_calendar['평균 기온'], 'rs--') #rs--, 스타일
plt.title('날짜별 기온', fontproperties=fontprop)
plt.ylabel('기온', fontproperties=fontprop)
plt.xlabel('날짜', fontproperties=fontprop)
plt.grid()
plt.show()
